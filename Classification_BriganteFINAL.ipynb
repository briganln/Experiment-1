# %% [markdown]
# <a href="https://colab.research.google.com/github/briganln/Experiment-1/blob/main/Classification_BriganteFINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive # mount google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
import numpy as np
import os
import pydot
from typing import List, Tuple
from matplotlib.pyplot import imshow
# %matplotlib inline
import matplotlib.pyplot as plt
import PIL.Image
import pathlib
import shutil

import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.preprocessing import image
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Model, load_model

from tensorflow.python.keras.utils import layer_utils
#from tensorflow.keras.utils.vis_utils import model_to_dot
from tensorflow.keras.utils import model_to_dot
from tensorflow.keras.utils import plot_model

from tensorflow.keras.applications.imagenet_utils import preprocess_input

from IPython.display import SVG

import scipy.misc

import tensorflow.keras.backend as K
K.set_image_data_format('channels_last') # can be channels_first or channels_last.
K.set_learning_phase(1) # 1 stands for learning phase
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(

# %%
def identity_block(X: tf.Tensor, level: int, block: int, filters: List[int]) -> tf.Tensor:
    """
    Creates an identity block (see figure 3.1 from readme)

    Input:
        X - input tensor of shape (m, height_prev, width_prev, chan_prev)
        level - integer, one of the 5 levels that our networks is conceptually divided into (see figure 3.1 in the readme file)
              - level names have the form: conv2_x, conv3_x ... conv5_x
        block - each conceptual level has multiple blocks (1 identity and several convolutional blocks)
                block is the number of this block within its conceptual layer
                i.e. first block from level 2 will be named conv2_1
        filters - a list on integers, each of them defining the number of filters in each convolutional layer

    Output:
        X - tensor (m, height, width, chan)
    """

    # layers will be called conv{level}_iden{block}_{convlayer_number_within_block}'
    conv_name = f'conv{level}_{block}' + '_{layer}_{type}'

    # unpack number of filters to be used for each conv layer
    f1, f2, f3 = filters

    # the shortcut branch of the identity block
    # takes the value of the block input
    X_shortcut = X

    # first convolutional layer (plus batch norm & relu activation, of course)
    X = Conv2D(filters=f1, kernel_size=(1, 1), strides=(1, 1),
               padding='valid', name=conv_name.format(layer=1, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=1, type='bn'))(X)
    X = Activation('relu', name=conv_name.format(layer=1, type='relu'))(X)

    # second convolutional layer
    X = Conv2D(filters=f2, kernel_size=(3, 3), strides=(1, 1),
               padding='same', name=conv_name.format(layer=2, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=2, type='bn'))(X)
    X = Activation('relu')(X)

    # third convolutional layer
    X = Conv2D(filters=f3, kernel_size=(1, 1), strides=(1, 1),
               padding='valid', name=conv_name.format(layer=3, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=3, type='bn'))(X)

    # add shortcut branch to main path
    X = Add()([X, X_shortcut])

    # relu activation at the end of the block
    X = Activation('relu', name=conv_name.format(layer=3, type='relu'))(X)

    return X

# %%
def convolutional_block(X: tf.Tensor, level: int, block: int, filters: List[int], s: Tuple[int,int,int]=(2, 2)) -> tf.Tensor:
    """
    Creates a convolutional block (see figure 3.1 from readme)

    Input:
        X - input tensor of shape (m, height_prev, width_prev, chan_prev)
        level - integer, one of the 5 levels that our networks is conceptually divided into (see figure 3.1 in the readme file)
              - level names have the form: conv2_x, conv3_x ... conv5_x
        block - each conceptual level has multiple blocks (1 identity and several convolutional blocks)
                block is the number of this block within its conceptual layer
                i.e. first block from level 2 will be named conv2_1
        filters - a list on integers, each of them defining the number of filters in each convolutional layer
        s   - stride of the first layer;
            - a conv layer with a filter that has a stride of 2 will reduce the width and height of its input by half

    Output:
        X - tensor (m, height, width, chan)
    """

    # layers will be called conv{level}_{block}_{convlayer_number_within_block}'
    conv_name = f'conv{level}_{block}' + '_{layer}_{type}'

    # unpack number of filters to be used for each conv layer
    f1, f2, f3 = filters

    # the shortcut branch of the convolutional block
    X_shortcut = X

    # first convolutional layer
    X = Conv2D(filters=f1, kernel_size=(1, 1), strides=s, padding='valid',
               name=conv_name.format(layer=1, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=1, type='bn'))(X)
    X = Activation('relu', name=conv_name.format(layer=1, type='relu'))(X)

    # second convolutional layer
    X = Conv2D(filters=f2, kernel_size=(3, 3), strides=(1, 1), padding='same',
               name=conv_name.format(layer=2, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=2, type='bn'))(X)
    X = Activation('relu', name=conv_name.format(layer=2, type='relu'))(X)

    # third convolutional layer
    X = Conv2D(filters=f3, kernel_size=(1, 1), strides=(1, 1), padding='valid',
               name=conv_name.format(layer=3, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=3, type='bn'))(X)

    # shortcut path
    X_shortcut = Conv2D(filters=f3, kernel_size=(1, 1), strides=s, padding='valid',
                        name=conv_name.format(layer='short', type='conv'),
                        kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=conv_name.format(layer='short', type='bn'))(X_shortcut)

    # add shortcut branch to main path
    X = Add()([X, X_shortcut])

    # nonlinearity
    X = Activation('relu', name=conv_name.format(layer=3, type='relu'))(X)

    return X

# %%
def ResNet50(input_size: Tuple[int,int,int], classes: int) -> Model:
    """
        Builds the ResNet50 model (see figure 4.2 from readme)

        Input:
            - input_size - a (height, width, chan) tuple, the shape of the input images
            - classes - number of classes the model must learn

        Output:
            model - a Keras Model() instance
    """

    # tensor placeholder for the model's input
    X_input = Input(input_size)

    ### Level 1 ###

    # padding
    X = ZeroPadding2D((3, 3))(X_input)

    # convolutional layer, followed by batch normalization and relu activation
    X = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2),
               name='conv1_1_1_conv',
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='conv1_1_1_nb')(X)
    X = Activation('relu')(X)

    ### Level 2 ###

    # max pooling layer to halve the size coming from the previous layer
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # 1x convolutional block
    X = convolutional_block(X, level=2, block=1, filters=[64, 64, 256], s=(1, 1))

    # 2x identity blocks
    X = identity_block(X, level=2, block=2, filters=[64, 64, 256])
    X = identity_block(X, level=2, block=3, filters=[64, 64, 256])

    ### Level 3 ###

    # 1x convolutional block
    X = convolutional_block(X, level=3, block=1, filters=[128, 128, 512], s=(2, 2))

    # 3x identity blocks
    X = identity_block(X, level=3, block=2, filters=[128, 128, 512])
    X = identity_block(X, level=3, block=3, filters=[128, 128, 512])
    X = identity_block(X, level=3, block=4, filters=[128, 128, 512])

    ### Level 4 ###
    # 1x convolutional block
    X = convolutional_block(X, level=4, block=1, filters=[256, 256, 1024], s=(2, 2))
    # 5x identity blocks
    X = identity_block(X, level=4, block=2, filters=[256, 256, 1024])
    X = identity_block(X, level=4, block=3, filters=[256, 256, 1024])
    X = identity_block(X, level=4, block=4, filters=[256, 256, 1024])
    X = identity_block(X, level=4, block=5, filters=[256, 256, 1024])
    X = identity_block(X, level=4, block=6, filters=[256, 256, 1024])

    ### Level 5 ###
    # 1x convolutional block
    X = convolutional_block(X, level=5, block=1, filters=[512, 512, 2048], s=(2, 2))
    # 2x identity blocks
    X = identity_block(X, level=5, block=2, filters=[512, 512, 2048])
    X = identity_block(X, level=5, block=3, filters=[512, 512, 2048])

    # Pooling layers
    X = AveragePooling2D(pool_size=(2, 2), name='avg_pool')(X)

    # Output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc_' + str(classes),
              kernel_initializer=glorot_uniform(seed=0))(X)

    # Create model
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
# set input image parameters
image_size = (224, 224)
channels = 3
num_classes = 2

# %%
model = ResNet50(input_size = (image_size[1], image_size[0], channels), classes = num_classes)

# %%
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 230, 230, 3)          0         ['input_1[0][0]']
#  g2D)
#
#  conv1_1_1_conv (Conv2D)     (None, 112, 112, 64)         9472      ['zero_padding2d[0][0]']
#
#  conv1_1_1_nb (BatchNormali  (None, 112, 112, 64)         256       ['conv1_1_1_conv[0][0]']
#  zation)
#
#  activation (Activation)     (None, 112, 112, 64)         0         ['conv1_1_1_nb[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 55, 55, 64)           0         ['activation[0][0]']
#  D)
#
#  conv2_1_1_conv (Conv2D)     (None, 55, 55, 64)           4160      ['max_pooling2d[0][0]']
#
#  conv2_1_1_bn (BatchNormali  (None, 55, 55, 64)           256       ['conv2_1_1_conv[0][0]']
#  zation)
#
#  conv2_1_1_relu (Activation  (None, 55, 55, 64)           0         ['conv2_1_1_bn[0][0]']
#  )
#
#  conv2_1_2_conv (Conv2D)     (None, 55, 55, 64)           36928     ['conv2_1_1_relu[0][0]']
#
#  conv2_1_2_bn (BatchNormali  (None, 55, 55, 64)           256       ['conv2_1_2_conv[0][0]']
#  zation)
#
#  conv2_1_2_relu (Activation  (None, 55, 55, 64)           0         ['conv2_1_2_bn[0][0]']
#  )
#
#  conv2_1_3_conv (Conv2D)     (None, 55, 55, 256)          16640     ['conv2_1_2_relu[0][0]']
#
#  conv2_1_short_conv (Conv2D  (None, 55, 55, 256)          16640     ['max_pooling2d[0][0]']
#  )
#
#  conv2_1_3_bn (BatchNormali  (None, 55, 55, 256)          1024      ['conv2_1_3_conv[0][0]']
#  zation)
#
#  conv2_1_short_bn (BatchNor  (None, 55, 55, 256)          1024      ['conv2_1_short_conv[0][0]']
#  malization)
#
#  add (Add)                   (None, 55, 55, 256)          0         ['conv2_1_3_bn[0][0]',
#                                                                      'conv2_1_short_bn[0][0]']
#
#  conv2_1_3_relu (Activation  (None, 55, 55, 256)          0         ['add[0][0]']
#  )
#
#  conv2_2_1_conv (Conv2D)     (None, 55, 55, 64)           16448     ['conv2_1_3_relu[0][0]']
#
#  conv2_2_1_bn (BatchNormali  (None, 55, 55, 64)           256       ['conv2_2_1_conv[0][0]']
#  zation)
#
#  conv2_2_1_relu (Activation  (None, 55, 55, 64)           0         ['conv2_2_1_bn[0][0]']
#  )
#
#  conv2_2_2_conv (Conv2D)     (None, 55, 55, 64)           36928     ['conv2_2_1_relu[0][0]']
#
#  conv2_2_2_bn (BatchNormali  (None, 55, 55, 64)           256       ['conv2_2_2_conv[0][0]']
#  zation)
#
#  activation_1 (Activation)   (None, 55, 55, 64)           0         ['conv2_2_2_bn[0][0]']
#
#  conv2_2_3_conv (Conv2D)     (None, 55, 55, 256)          16640     ['activation_1[0][0]']
#
#  conv2_2_3_bn (BatchNormali  (None, 55, 55, 256)          1024      ['conv2_2_3_conv[0][0]']
#  zation)
#
#  add_1 (Add)                 (None, 55, 55, 256)          0         ['conv2_2_3_bn[0][0]',
#                                                                      'conv2_1_3_relu[0][0]']
#
#  conv2_2_3_relu (Activation  (None, 55, 55, 256)          0         ['add_1[0][0]']
#  )
#
#  conv2_3_1_conv (Conv2D)     (None, 55, 55, 64)           16448     ['conv2_2_3_relu[0][0]']
#
#  conv2_3_1_bn (BatchNormali  (None, 55, 55, 64)           256       ['conv2_3_1_conv[0][0]']
#  zation)
#
#  conv2_3_1_relu (Activation  (None, 55, 55, 64)           0         ['conv2_3_1_bn[0][0]']
#  )
#
#  conv2_3_2_conv (Conv2D)     (None, 55, 55, 64)           36928     ['conv2_3_1_relu[0][0]']
#
#  conv2_3_2_bn (BatchNormali  (None, 55, 55, 64)           256       ['conv2_3_2_conv[0][0]']
#  zation)
#
#  activation_2 (Activation)   (None, 55, 55, 64)           0         ['conv2_3_2_bn[0][0]']
#
#  conv2_3_3_conv (Conv2D)     (None, 55, 55, 256)          16640     ['activation_2[0][0]']
#
#  conv2_3_3_bn (BatchNormali  (None, 55, 55, 256)          1024      ['conv2_3_3_conv[0][0]']
#  zation)
#
#  add_2 (Add)                 (None, 55, 55, 256)          0         ['conv2_3_3_bn[0][0]',
#                                                                      'conv2_2_3_relu[0][0]']
#
#  conv2_3_3_relu (Activation  (None, 55, 55, 256)          0         ['add_2[0][0]']
#  )
#
#  conv3_1_1_conv (Conv2D)     (None, 28, 28, 128)          32896     ['conv2_3_3_relu[0][0]']
#
#  conv3_1_1_bn (BatchNormali  (None, 28, 28, 128)          512       ['conv3_1_1_conv[0][0]']
#  zation)
#
#  conv3_1_1_relu (Activation  (None, 28, 28, 128)          0         ['conv3_1_1_bn[0][0]']
#  )
#
#  conv3_1_2_conv (Conv2D)     (None, 28, 28, 128)          147584    ['conv3_1_1_relu[0][0]']
#
#  conv3_1_2_bn (BatchNormali  (None, 28, 28, 128)          512       ['conv3_1_2_conv[0][0]']
#  zation)
#
#  conv3_1_2_relu (Activation  (None, 28, 28, 128)          0         ['conv3_1_2_bn[0][0]']
#  )
#
#  conv3_1_3_conv (Conv2D)     (None, 28, 28, 512)          66048     ['conv3_1_2_relu[0][0]']
#
#  conv3_1_short_conv (Conv2D  (None, 28, 28, 512)          131584    ['conv2_3_3_relu[0][0]']
#  )
#
#  conv3_1_3_bn (BatchNormali  (None, 28, 28, 512)          2048      ['conv3_1_3_conv[0][0]']
#  zation)
#
#  conv3_1_short_bn (BatchNor  (None, 28, 28, 512)          2048      ['conv3_1_short_conv[0][0]']
#  malization)
#
#  add_3 (Add)                 (None, 28, 28, 512)          0         ['conv3_1_3_bn[0][0]',
#                                                                      'conv3_1_short_bn[0][0]']
#
#  conv3_1_3_relu (Activation  (None, 28, 28, 512)          0         ['add_3[0][0]']
#  )
#
#  conv3_2_1_conv (Conv2D)     (None, 28, 28, 128)          65664     ['conv3_1_3_relu[0][0]']
#
#  conv3_2_1_bn (BatchNormali  (None, 28, 28, 128)          512       ['conv3_2_1_conv[0][0]']
#  zation)
#
#  conv3_2_1_relu (Activation  (None, 28, 28, 128)          0         ['conv3_2_1_bn[0][0]']
#  )
#
#  conv3_2_2_conv (Conv2D)     (None, 28, 28, 128)          147584    ['conv3_2_1_relu[0][0]']
#
#  conv3_2_2_bn (BatchNormali  (None, 28, 28, 128)          512       ['conv3_2_2_conv[0][0]']
#  zation)
#
#  activation_3 (Activation)   (None, 28, 28, 128)          0         ['conv3_2_2_bn[0][0]']
#
#  conv3_2_3_conv (Conv2D)     (None, 28, 28, 512)          66048     ['activation_3[0][0]']
#
#  conv3_2_3_bn (BatchNormali  (None, 28, 28, 512)          2048      ['conv3_2_3_conv[0][0]']
#  zation)
#
#  add_4 (Add)                 (None, 28, 28, 512)          0         ['conv3_2_3_bn[0][0]',
#                                                                      'conv3_1_3_relu[0][0]']
#
#  conv3_2_3_relu (Activation  (None, 28, 28, 512)          0         ['add_4[0][0]']
#  )
#
#  conv3_3_1_conv (Conv2D)     (None, 28, 28, 128)          65664     ['conv3_2_3_relu[0][0]']
#
#  conv3_3_1_bn (BatchNormali  (None, 28, 28, 128)          512       ['conv3_3_1_conv[0][0]']
#  zation)
#
#  conv3_3_1_relu (Activation  (None, 28, 28, 128)          0         ['conv3_3_1_bn[0][0]']
#  )
#
#  conv3_3_2_conv (Conv2D)     (None, 28, 28, 128)          147584    ['conv3_3_1_relu[0][0]']
#
#  conv3_3_2_bn (BatchNormali  (None, 28, 28, 128)          512       ['conv3_3_2_conv[0][0]']
#  zation)
#
#  activation_4 (Activation)   (None, 28, 28, 128)          0         ['conv3_3_2_bn[0][0]']
#
#  conv3_3_3_conv (Conv2D)     (None, 28, 28, 512)          66048     ['activation_4[0][0]']
#
#  conv3_3_3_bn (BatchNormali  (None, 28, 28, 512)          2048      ['conv3_3_3_conv[0][0]']
#  zation)
#
#  add_5 (Add)                 (None, 28, 28, 512)          0         ['conv3_3_3_bn[0][0]',
#                                                                      'conv3_2_3_relu[0][0]']
#
#  conv3_3_3_relu (Activation  (None, 28, 28, 512)          0         ['add_5[0][0]']
#  )
#
#  conv3_4_1_conv (Conv2D)     (None, 28, 28, 128)          65664     ['conv3_3_3_relu[0][0]']
#
#  conv3_4_1_bn (BatchNormali  (None, 28, 28, 128)          512       ['conv3_4_1_conv[0][0]']
#  zation)
#
#  conv3_4_1_relu (Activation  (None, 28, 28, 128)          0         ['conv3_4_1_bn[0][0]']
#  )
#
#  conv3_4_2_conv (Conv2D)     (None, 28, 28, 128)          147584    ['conv3_4_1_relu[0][0]']
#
#  conv3_4_2_bn (BatchNormali  (None, 28, 28, 128)          512       ['conv3_4_2_conv[0][0]']
#  zation)
#
#  activation_5 (Activation)   (None, 28, 28, 128)          0         ['conv3_4_2_bn[0][0]']
#
#  conv3_4_3_conv (Conv2D)     (None, 28, 28, 512)          66048     ['activation_5[0][0]']
#
#  conv3_4_3_bn (BatchNormali  (None, 28, 28, 512)          2048      ['conv3_4_3_conv[0][0]']
#  zation)
#
#  add_6 (Add)                 (None, 28, 28, 512)          0         ['conv3_4_3_bn[0][0]',
#                                                                      'conv3_3_3_relu[0][0]']
#
#  conv3_4_3_relu (Activation  (None, 28, 28, 512)          0         ['add_6[0][0]']
#  )
#
#  conv4_1_1_conv (Conv2D)     (None, 14, 14, 256)          131328    ['conv3_4_3_relu[0][0]']
#
#  conv4_1_1_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_1_1_conv[0][0]']
#  zation)
#
#  conv4_1_1_relu (Activation  (None, 14, 14, 256)          0         ['conv4_1_1_bn[0][0]']
#  )
#
#  conv4_1_2_conv (Conv2D)     (None, 14, 14, 256)          590080    ['conv4_1_1_relu[0][0]']
#
#  conv4_1_2_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_1_2_conv[0][0]']
#  zation)
#
#  conv4_1_2_relu (Activation  (None, 14, 14, 256)          0         ['conv4_1_2_bn[0][0]']
#  )
#
#  conv4_1_3_conv (Conv2D)     (None, 14, 14, 1024)         263168    ['conv4_1_2_relu[0][0]']
#
#  conv4_1_short_conv (Conv2D  (None, 14, 14, 1024)         525312    ['conv3_4_3_relu[0][0]']
#  )
#
#  conv4_1_3_bn (BatchNormali  (None, 14, 14, 1024)         4096      ['conv4_1_3_conv[0][0]']
#  zation)
#
#  conv4_1_short_bn (BatchNor  (None, 14, 14, 1024)         4096      ['conv4_1_short_conv[0][0]']
#  malization)
#
#  add_7 (Add)                 (None, 14, 14, 1024)         0         ['conv4_1_3_bn[0][0]',
#                                                                      'conv4_1_short_bn[0][0]']
#
#  conv4_1_3_relu (Activation  (None, 14, 14, 1024)         0         ['add_7[0][0]']
#  )
#
#  conv4_2_1_conv (Conv2D)     (None, 14, 14, 256)          262400    ['conv4_1_3_relu[0][0]']
#
#  conv4_2_1_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_2_1_conv[0][0]']
#  zation)
#
#  conv4_2_1_relu (Activation  (None, 14, 14, 256)          0         ['conv4_2_1_bn[0][0]']
#  )
#
#  conv4_2_2_conv (Conv2D)     (None, 14, 14, 256)          590080    ['conv4_2_1_relu[0][0]']
#
#  conv4_2_2_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_2_2_conv[0][0]']
#  zation)
#
#  activation_6 (Activation)   (None, 14, 14, 256)          0         ['conv4_2_2_bn[0][0]']
#
#  conv4_2_3_conv (Conv2D)     (None, 14, 14, 1024)         263168    ['activation_6[0][0]']
#
#  conv4_2_3_bn (BatchNormali  (None, 14, 14, 1024)         4096      ['conv4_2_3_conv[0][0]']
#  zation)
#
#  add_8 (Add)                 (None, 14, 14, 1024)         0         ['conv4_2_3_bn[0][0]',
#                                                                      'conv4_1_3_relu[0][0]']
#
#  conv4_2_3_relu (Activation  (None, 14, 14, 1024)         0         ['add_8[0][0]']
#  )
#
#  conv4_3_1_conv (Conv2D)     (None, 14, 14, 256)          262400    ['conv4_2_3_relu[0][0]']
#
#  conv4_3_1_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_3_1_conv[0][0]']
#  zation)
#
#  conv4_3_1_relu (Activation  (None, 14, 14, 256)          0         ['conv4_3_1_bn[0][0]']
#  )
#
#  conv4_3_2_conv (Conv2D)     (None, 14, 14, 256)          590080    ['conv4_3_1_relu[0][0]']
#
#  conv4_3_2_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_3_2_conv[0][0]']
#  zation)
#
#  activation_7 (Activation)   (None, 14, 14, 256)          0         ['conv4_3_2_bn[0][0]']
#
#  conv4_3_3_conv (Conv2D)     (None, 14, 14, 1024)         263168    ['activation_7[0][0]']
#
#  conv4_3_3_bn (BatchNormali  (None, 14, 14, 1024)         4096      ['conv4_3_3_conv[0][0]']
#  zation)
#
#  add_9 (Add)                 (None, 14, 14, 1024)         0         ['conv4_3_3_bn[0][0]',
#                                                                      'conv4_2_3_relu[0][0]']
#
#  conv4_3_3_relu (Activation  (None, 14, 14, 1024)         0         ['add_9[0][0]']
#  )
#
#  conv4_4_1_conv (Conv2D)     (None, 14, 14, 256)          262400    ['conv4_3_3_relu[0][0]']
#
#  conv4_4_1_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_4_1_conv[0][0]']
#  zation)
#
#  conv4_4_1_relu (Activation  (None, 14, 14, 256)          0         ['conv4_4_1_bn[0][0]']
#  )
#
#  conv4_4_2_conv (Conv2D)     (None, 14, 14, 256)          590080    ['conv4_4_1_relu[0][0]']
#
#  conv4_4_2_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_4_2_conv[0][0]']
#  zation)
#
#  activation_8 (Activation)   (None, 14, 14, 256)          0         ['conv4_4_2_bn[0][0]']
#
#  conv4_4_3_conv (Conv2D)     (None, 14, 14, 1024)         263168    ['activation_8[0][0]']
#
#  conv4_4_3_bn (BatchNormali  (None, 14, 14, 1024)         4096      ['conv4_4_3_conv[0][0]']
#  zation)
#
#  add_10 (Add)                (None, 14, 14, 1024)         0         ['conv4_4_3_bn[0][0]',
#                                                                      'conv4_3_3_relu[0][0]']
#
#  conv4_4_3_relu (Activation  (None, 14, 14, 1024)         0         ['add_10[0][0]']
#  )
#
#  conv4_5_1_conv (Conv2D)     (None, 14, 14, 256)          262400    ['conv4_4_3_relu[0][0]']
#
#  conv4_5_1_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_5_1_conv[0][0]']
#  zation)
#
#  conv4_5_1_relu (Activation  (None, 14, 14, 256)          0         ['conv4_5_1_bn[0][0]']
#  )
#
#  conv4_5_2_conv (Conv2D)     (None, 14, 14, 256)          590080    ['conv4_5_1_relu[0][0]']
#
#  conv4_5_2_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_5_2_conv[0][0]']
#  zation)
#
#  activation_9 (Activation)   (None, 14, 14, 256)          0         ['conv4_5_2_bn[0][0]']
#
#  conv4_5_3_conv (Conv2D)     (None, 14, 14, 1024)         263168    ['activation_9[0][0]']
#
#  conv4_5_3_bn (BatchNormali  (None, 14, 14, 1024)         4096      ['conv4_5_3_conv[0][0]']
#  zation)
#
#  add_11 (Add)                (None, 14, 14, 1024)         0         ['conv4_5_3_bn[0][0]',
#                                                                      'conv4_4_3_relu[0][0]']
#
#  conv4_5_3_relu (Activation  (None, 14, 14, 1024)         0         ['add_11[0][0]']
#  )
#
#  conv4_6_1_conv (Conv2D)     (None, 14, 14, 256)          262400    ['conv4_5_3_relu[0][0]']
#
#  conv4_6_1_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_6_1_conv[0][0]']
#  zation)
#
#  conv4_6_1_relu (Activation  (None, 14, 14, 256)          0         ['conv4_6_1_bn[0][0]']
#  )
#
#  conv4_6_2_conv (Conv2D)     (None, 14, 14, 256)          590080    ['conv4_6_1_relu[0][0]']
#
#  conv4_6_2_bn (BatchNormali  (None, 14, 14, 256)          1024      ['conv4_6_2_conv[0][0]']
#  zation)
#
#  activation_10 (Activation)  (None, 14, 14, 256)          0         ['conv4_6_2_bn[0][0]']
#
#  conv4_6_3_conv (Conv2D)     (None, 14, 14, 1024)         263168    ['activation_10[0][0]']
#
#  conv4_6_3_bn (BatchNormali  (None, 14, 14, 1024)         4096      ['conv4_6_3_conv[0][0]']
#  zation)
#
#  add_12 (Add)                (None, 14, 14, 1024)         0         ['conv4_6_3_bn[0][0]',
#                                                                      'conv4_5_3_relu[0][0]']
#
#  conv4_6_3_relu (Activation  (None, 14, 14, 1024)         0         ['add_12[0][0]']
#  )
#
#  conv5_1_1_conv (Conv2D)     (None, 7, 7, 512)            524800    ['conv4_6_3_relu[0][0]']
#
#  conv5_1_1_bn (BatchNormali  (None, 7, 7, 512)            2048      ['conv5_1_1_conv[0][0]']
#  zation)
#
#  conv5_1_1_relu (Activation  (None, 7, 7, 512)            0         ['conv5_1_1_bn[0][0]']
#  )
#
#  conv5_1_2_conv (Conv2D)     (None, 7, 7, 512)            2359808   ['conv5_1_1_relu[0][0]']
#
#  conv5_1_2_bn (BatchNormali  (None, 7, 7, 512)            2048      ['conv5_1_2_conv[0][0]']
#  zation)
#
#  conv5_1_2_relu (Activation  (None, 7, 7, 512)            0         ['conv5_1_2_bn[0][0]']
#  )
#
#  conv5_1_3_conv (Conv2D)     (None, 7, 7, 2048)           1050624   ['conv5_1_2_relu[0][0]']
#
#  conv5_1_short_conv (Conv2D  (None, 7, 7, 2048)           2099200   ['conv4_6_3_relu[0][0]']
#  )
#
#  conv5_1_3_bn (BatchNormali  (None, 7, 7, 2048)           8192      ['conv5_1_3_conv[0][0]']
#  zation)
#
#  conv5_1_short_bn (BatchNor  (None, 7, 7, 2048)           8192      ['conv5_1_short_conv[0][0]']
#  malization)
#
#  add_13 (Add)                (None, 7, 7, 2048)           0         ['conv5_1_3_bn[0][0]',
#                                                                      'conv5_1_short_bn[0][0]']
#
#  conv5_1_3_relu (Activation  (None, 7, 7, 2048)           0         ['add_13[0][0]']
#  )
#
#  conv5_2_1_conv (Conv2D)     (None, 7, 7, 512)            1049088   ['conv5_1_3_relu[0][0]']
#
#  conv5_2_1_bn (BatchNormali  (None, 7, 7, 512)            2048      ['conv5_2_1_conv[0][0]']
#  zation)
#
#  conv5_2_1_relu (Activation  (None, 7, 7, 512)            0         ['conv5_2_1_bn[0][0]']
#  )
#
#  conv5_2_2_conv (Conv2D)     (None, 7, 7, 512)            2359808   ['conv5_2_1_relu[0][0]']
#
#  conv5_2_2_bn (BatchNormali  (None, 7, 7, 512)            2048      ['conv5_2_2_conv[0][0]']
#  zation)
#
#  activation_11 (Activation)  (None, 7, 7, 512)            0         ['conv5_2_2_bn[0][0]']
#
#  conv5_2_3_conv (Conv2D)     (None, 7, 7, 2048)           1050624   ['activation_11[0][0]']
#
#  conv5_2_3_bn (BatchNormali  (None, 7, 7, 2048)           8192      ['conv5_2_3_conv[0][0]']
#  zation)
#
#  add_14 (Add)                (None, 7, 7, 2048)           0         ['conv5_2_3_bn[0][0]',
#                                                                      'conv5_1_3_relu[0][0]']
#
#  conv5_2_3_relu (Activation  (None, 7, 7, 2048)           0         ['add_14[0][0]']
#  )
#
#  conv5_3_1_conv (Conv2D)     (None, 7, 7, 512)            1049088   ['conv5_2_3_relu[0][0]']
#
#  conv5_3_1_bn (BatchNormali  (None, 7, 7, 512)            2048      ['conv5_3_1_conv[0][0]']
#  zation)
#
#  conv5_3_1_relu (Activation  (None, 7, 7, 512)            0         ['conv5_3_1_bn[0][0]']
#  )
#
#  conv5_3_2_conv (Conv2D)     (None, 7, 7, 512)            2359808   ['conv5_3_1_relu[0][0]']
#
#  conv5_3_2_bn (BatchNormali  (None, 7, 7, 512)            2048      ['conv5_3_2_conv[0][0]']
#  zation)
#
#  activation_12 (Activation)  (None, 7, 7, 512)            0         ['conv5_3_2_bn[0][0]']
#
#  conv5_3_3_conv (Conv2D)     (None, 7, 7, 2048)           1050624   ['activation_12[0][0]']
#
#  conv5_3_3_bn (BatchNormali  (None, 7, 7, 2048)           8192      ['conv5_3_3_conv[0][0]']
#  zation)
#
#  add_15 (Add)                (None, 7, 7, 2048)           0         ['conv5_3_3_bn[0][0]',
#                                                                      'conv5_2_3_relu[0][0]']
#
#  conv5_3_3_relu (Activation  (None, 7, 7, 2048)           0         ['add_15[0][0]']
#  )
#
#  avg_pool (AveragePooling2D  (None, 3, 3, 2048)           0         ['conv5_3_3_relu[0][0]']
#  )
#
#  flatten (Flatten)           (None, 18432)                0         ['avg_pool[0][0]']
#
#  fc_2 (Dense)                (None, 2)                    36866     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 23624578 (90.12 MB)
# Trainable params: 23571458 (89.92 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
# path to desired image set, relative to current working dir
in_folder = os.path.join('/content/drive/MyDrive/Classification/images_train_sorted3')

file_count = []

# get number of images in each folder (images per class)
for fld in os.listdir(in_folder):
    crt = os.path.join(in_folder, fld)

    image_count = len(os.listdir(crt))

    file_count.append(image_count)

    print(f'{crt} contains {image_count} images')
# Out:
# /content/drive/MyDrive/Classification/images_train_sorted3/hp contains 1499 images
# /content/drive/MyDrive/Classification/images_train_sorted3/ssa contains 674 images

# %%
print(f'Total number of images: {sum(file_count)}')
# Out:
# Total number of images: 2173

# %%
os.listdir(os.path.join(in_folder, 'hp'))[:10]
# Out:
# ['MHIST_byj.png',
#  'MHIST_chh.png',
#  'MHIST_cwd.png',
#  'MHIST_cet.png',
#  'MHIST_bto.png',
#  'MHIST_dgb.png',
#  'MHIST_dkw.png',
#  'MHIST_cen.png',
#  'MHIST_btj.png',
#  'MHIST_ded.png']

# %%
data_dir = pathlib.Path(in_folder)

hp = list(data_dir.glob('hp/*'))

PIL.Image.open(str(hp[0]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
PIL.Image.open(str(hp[0])).size
# Out:
# (224, 224)

# %%
PIL.Image.open(str(hp[10]))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
PIL.Image.open(str(hp[10])).size
# Out:
# (224, 224)

# %%
# path to output folder, relative to current working dir
out_folder = os.path.join('/content/drive/MyDrive/Classification/images_train_output3')

# %%
def square_crop_image(im: PIL.Image) -> PIL.Image:
    width, height = im.size
    new_size = min(width, height)

    # center crop
    left = (width - new_size) / 2
    top = (height - new_size) / 2
    right = (width + new_size) / 2
    bottom = (height + new_size) / 2

    crop_im = im.crop((left, top, right, bottom))
    crop_im = crop_im.convert('RGB')

    return crop_im

# %%
def make_dataset(in_folder, im_per_class):
    # iterate through all folders (there should be one folder per object class)
    for fld in os.listdir(in_folder):
        # create the output folder for processed images for current class
        # delete folder and contents if there is one already
        out = os.path.join(out_folder, fld)
        if os.path.exists(out):
            shutil.rmtree(out)
        os.makedirs(out)

        fld_path = pathlib.Path(os.path.join(in_folder, fld))
        num_images = 0
        for file in list(fld_path.glob('*')):
            # open image, center crop to a square
            # save to the output folder
            with PIL.Image.open(file) as im:
                crop_im = square_crop_image(im)
                crop_im.save(os.path.join(out, str(num_images) + '.jpg'))
                #im.close()
            # break when desired number of images
            # has been processed (to keep classes balance)
            num_images = num_images + 1
            if (num_images > im_per_class):
                break

# %%
#open(in_folder, 'r+')

# get the number of images that will make our classes balanced
im_per_class = min(file_count)

# process input images
make_dataset(in_folder, im_per_class)

# %%
img_height = image_size[1]
img_width = image_size[0]
batch_size = 32

# %%
data_dir = pathlib.Path(out_folder)

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split = 0.3,
    subset="training",
    label_mode='categorical', # default mode is 'int' label, but we want one-hot encoded labels (e.g. for categorical_crossentropy loss)
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=0.3,
    subset="validation",
    label_mode='categorical',
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)
# Out:
# Found 1349 files belonging to 2 classes.
# Using 945 files for training.
# Found 1349 files belonging to 2 classes.
# Using 404 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['hp', 'ssa']

# %%
plt.figure(figsize=(10, 10))

i = 1

for images, labels in train_ds.take(1):
    for (image, label) in zip(images, labels):
        ax = plt.subplot(4, 4, i)
        plt.imshow(image.numpy().astype("uint8"))
        plt.title(class_names[tf.argmax(label, axis=0)])
        plt.axis("off")
        i = i + 1
        if i == 17:
            break
plt.show()

# %%
# use keras functionality for adding a rescaling layer
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# rescale training and validation sets
norm_train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
norm_val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
image_batch, labels_batch = next(iter(norm_train_ds))

# get one image
first_image = image_batch[0]

# confirm pixel values are now in the [0,1] range
print(np.min(first_image), np.max(first_image))
# Out:
# 0.03529412 1.0

# %%
model.compile(
    optimizer='adam', # optimizer
    loss='categorical_crossentropy', # loss function to optimize
    metrics=['accuracy'] # metrics to monitor
)

# %%
AUTOTUNE = tf.data.AUTOTUNE

norm_train_ds = norm_train_ds.cache().prefetch(buffer_size=AUTOTUNE)
norm_val_ds = norm_val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
model_on_gpu = ResNet50(input_size = (image_size[1], image_size[0], channels), classes = num_classes)
model_on_gpu.compile(
    optimizer='adam', # optimizer
    loss='categorical_crossentropy', # loss function to optimize
    metrics=['accuracy'] # metrics to monitor
)

# %%
device_name = tf.test.gpu_device_name()
if "GPU" not in device_name:
    print("GPU device not found")
print('Found GPU at: {}'.format(device_name))
# Out:
# GPU device not found
# Found GPU at:

# %%
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss", # monitor validation loss (that is, the loss computed for the validation holdout)
        min_delta=1e-2, # "no longer improving" being defined as "an improvement lower than 1e-2"
        patience=10, # "no longer improving" being further defined as "for at least 10 consecutive epochs"
        verbose=1
    )
]

# %%
start = time.time()
with tf.device('/gpu:0'):
    history = model_on_gpu.fit(
        norm_train_ds,
        validation_data=norm_val_ds,
        epochs=20,
        callbacks=callbacks,
    )
stop = time.time()
print(f'Training on GPU took: {(stop-start)/60} minutes')
# Out:
# Epoch 1/20
# 34/34 [==============================] - 919s 27s/step - loss: 1.3115 - accuracy: 0.5407 - val_loss: 2.9795 - val_accuracy: 0.5465
# Epoch 2/20
# 34/34 [==============================] - 878s 26s/step - loss: 1.5622 - accuracy: 0.6120 - val_loss: 0.7808 - val_accuracy: 0.4981
# Epoch 3/20
# 34/34 [==============================] - 917s 27s/step - loss: 1.2558 - accuracy: 0.5796 - val_loss: 9.3554 - val_accuracy: 0.4870
# Epoch 4/20
# 34/34 [==============================] - 917s 27s/step - loss: 0.8735 - accuracy: 0.6630 - val_loss: 64.9516 - val_accuracy: 0.4498
# Epoch 5/20
# 34/34 [==============================] - 884s 26s/step - loss: 0.7982 - accuracy: 0.6463 - val_loss: 6.4700 - val_accuracy: 0.4535
# Epoch 6/20
# 34/34 [==============================] - 893s 26s/step - loss: 0.8397 - accuracy: 0.6870 - val_loss: 4.3515 - val_accuracy: 0.4572
# Epoch 7/20
# 34/34 [==============================] - 878s 26s/step - loss: 0.7541 - accuracy: 0.6417 - val_loss: 2.4540 - val_accuracy: 0.4349
# Epoch 8/20
# 34/34 [==============================] - 926s 27s/step - loss: 0.6871 - accuracy: 0.6463 - val_loss: 50.4452 - val_accuracy: 0.4535
# Epoch 9/20
# 34/34 [==============================] - 894s 26s/step - loss: 0.5312 - accuracy: 0.7389 - val_loss: 12.7162 - val_accuracy: 0.4535
# Epoch 10/20
# 34/34 [==============================] - 842s 25s/step - loss: 0.4220 - accuracy: 0.7954 - val_loss: 4.4302 - val_accuracy: 0.4981
# Epoch 11/20
# 34/34 [==============================] - 874s 26s/step - loss: 0.2972 - accuracy: 0.8722 - val_loss: 1.6532 - val_accuracy: 0.4870
# Epoch 12/20
# 34/34 [==============================] - 959s 28s/step - loss: 0.2533 - accuracy: 0.8954 - val_loss: 0.9850 - val_accuracy: 0.5799
# Epoch 12: early stopping
# Training on GPU took: 182.70283085505167 minutes

# %%
print(history.history.keys())

plt.figure(figsize=(12, 10))

# summarize history for accuracy
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

# summarize history for loss
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#preds = model_on_gpu.evaluate(X_test, Y_test)
preds = model_on_gpu.evaluate(norm_val_ds)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 9/9 [==============================] - 55s 6s/step - loss: 0.9850 - accuracy: 0.5799
# Loss = 0.9850159883499146
# Test Accuracy = 0.5799256563186646

# %%
import cv2

test_img_path = '/content/drive/MyDrive/Classification/images_eval/MHIST_cfc.png'

# read image
img = cv2.imread(test_img_path)

# reorder RGB channels (opencv reads as BGR by default)
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# resize to the same input image size that we used when defining the model architecture
x = cv2.resize(RGB_img, image_size, interpolation = cv2.INTER_AREA)

print('Input image shape:', x.shape) # sanity check

plt.imshow(RGB_img)
# Out:
# Input image shape: (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0) # fake batch size dimension
x = x/255.0 # normalize pixel values to [0,1] interval

preds = model_on_gpu.predict(x) # get model predictions

print("Model's prediction has this format: [p(0), p(1), ... , p(5)] = ")
print(preds)



print("The prediction for this image is: ", class_names[np.argmax(preds)])
# Out:
# 1/1 [==============================] - 2s 2s/step
# Model's prediction has this format: [p(0), p(1), ... , p(5)] =
# [[0.0380232 0.9619768]]
# The prediction for this image is:  ssa

# %%
len(preds[0])

for i, p in enumerate(preds[0]):
    print(f'p:{p:.05f}\t{class_names[i]}')
# Out:
# p:0.03802	hp
# p:0.96198	ssa

# %%
print(history.history.keys())

plt.figure(figsize=(12, 10))

# summarize history for accuracy
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

# summarize history for loss
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#correct = 0
#total = 0
#with torch.no_grad():
    #for data in testloader:
        #images, labels = data
        #outputs = ResNet50(images)
        #_, predicted = torch.max(outputs.data, 1)
        #total += labels.size(0)
        #correct += (predicted == labels).sum().item()

#print('Accuracy of the network on the 10000 test images: %d %%' % (
    #100 * correct / total))

# %%
#criterion = nn.CrossEntropyLoss() #need a loss - need good classification to follow (look for examples onlien)
#optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
